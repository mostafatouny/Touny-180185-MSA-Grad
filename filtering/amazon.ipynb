# %%
import module.readData.main as jsonHandler
import module.filterData.main as filterData
import module.filterData.constant_REs as con_REs

# %%
# only once
#import nltk
#nltk.download('stopwords')

# %% [markdown]
# ___

# %% [markdown]
# ## Query Data Live From Twitter
# source: [@Amazon](https://twitter.com/amazon)

# %% [markdown]
# It is out of this notebook's scope

# %% [markdown]
# ___

# %% [markdown]
# ## Read Data

# %%
dataDict = jsonHandler.readJson("./amazon.json")

# %% [markdown]
# ___

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Fetch Tweets Text List

# %%
# inspect raw data
dataDict
# Out:
# {'data': [{'id': '1337214201622827010',
#    'text': '@amazon Her name is Izzy! :)'},
#   {'id': '1337898856483188736',
#    'text': "Got some amazon packages and had sibling open them and put them under the tree for me. Thank you santa's elves #tbtbsanta"},
#   {'id': '1337922297617809408',
#    'text': "@amazon Hahaha she's super creative. Loves to make stuff, arts &amp; crafts, drawing, painting, etc. She's a smart cookie for sure 😂❤"},
#   {'id': '1337878827121328128',
#    'text': 'I love Amazon Fresh. I can have all my groceries delivered in two hours 🙌🏻 https://t.co/8qcBdOh3wy'},
#   {'id': '1336235270245650432',
#    'text': "This purple wig is so pretty! Amazon is awesome for wigs. I'm barely getting by mentally at work and doing this is an amazing release for me. https://t.co/mqQaSWCf6a"},
#   {'id': '1337899140055875587',
#    'text': 'When your parents live out of state and they bought your presents on Amazon but you also buy shit on Amazon so you have to ask permission to open your own packages cause you don’t want to ruin Christmas https://t.co/rDikf3T7qe'},
#   {'id': '1337757268415287298',
#    'text': 'Amazon never fail me ain’t lying 🤣🥴.'},
#   {'id': '1337620149747109888',
#    'text': 'Christmas time is oh so cozy at my apartment! 1st Christmas here&amp; I absolutely love it! ❤️🌟🎄✨ My Christmas tree skirt is from @amazon 🥰 https://t.co/NUdM88qenq'},
#   {'id': '1337877591923912706',
#    'text': "Working on school stuff with my 6yo daughter*\n\n6yo: How do you spell 'want'?\n\nMe: Try to sound it out, please.\n\n6yo: ALEXA! HOW DO YOU SPELL WANT?!\n\nAlexa: Want is spelled... w-a-n-t\n\nMe:...\n\nAlexa is now muted.\n\n#parenting #dadlife #alexastop"},
#   {'id': '1337289995753836546',
#    'text': 'Dear Amazon prime, you a real one for those of us who have to wait till payday to buy Christmas presents. ‘Preciate ya'},
#   {'id': '1334661813376602114',
#    'text': 'Why yes, I did search for “Bulbasaur Planter” on Amazon because I was looking to make my desk a little more adorable. https://t.co/ukbXCyP3Pd'},
#   {'id': '1337161663871655939',
#    'text': 'Welp people, momlady sezs “time to send the returns back to Amazon”😹😹😹\nWinkie be jokin ya. They not send me back😼😼🐾they lubs me https://t.co/unFaCZpR5z'},
#   {'id': '1337851692541497348',
#    'text': "I have to give a HUGE shoutout to @amazon for hooking myself and my little fur family up with some gifts! Jackson &amp; Lincoln love their gifts. I'm super excited I got the tetris lights I've been looking at for awhile! We are so grateful that you did this for us. Thank you!!💕 https://t.co/HBqWYAk4G4"},
#   {'id': '1335638921179500545',
#    'text': 'Max: Mom!! Amazon messed up my order! I ordered treats but they sent me a kitten in a box!! 😺🐾 Can we send her back?? 😹🐾 \nWe hope everyone is having a nice Sunday ☀️\n\n#CatsOfTwitter  #cats #catboxsunday https://t.co/9lXlpPQk6Q'},
#   {'id': '1337828354037325824',
#    'text': 'I need to order so much stuff on amazon 😩'},
#   {'id': '1337830412937269249',
#    'text': '@amazon I recently purchased a magnetic phone holder from you and I pulled it off and it’s cracked my phone https://t.co/vRgTDbGmKB'},
#   {'id': '1337600627791302659',
#    'text': 'I’m excited to get my supernatural merch I’ve ordered off of Amazon in the mail new shirt, new string bag and my dean amulet necklace to come in yes 👍'},
#   {'id': '1337818692063813638',
#    'text': 'I ordered 3 books from Amazon, 2 books came yesterday &amp; one arrived this morning~❤💕❤ https://t.co/9qN1BVh6rA'},
#   {'id': '1337819689435664386',
#    'text': 'Amazon prime has been my best friend. Need something for the baby? Bet order it real quick, here within hours or the next day. LIFESAVER 😆'},
#   {'id': '1337384086525145089',
#    'text': 'God I love my echo products!! I just used my echo show to broadcast revile through my whole house to wake up my daughters!! #prouddadmoment oh FYI they weren’t amused!'},
#   {'id': '1337607884285353985', 'text': 'Amazon prime is amazing lol'},
#   {'id': '1337805274535571458',
#    'text': 'How brilliant is this - my @amazon delivery vehicle is a sleigh😆🎅🏻🎄 https://t.co/XNASd20MaE'},
#   {'id': '1337553706158592002',
#    'text': '@AmazonHelp I submitted my info, thanks!'},
#   {'id': '1337784323936833536',
#    'text': 'Finally done with all my Christmas shopping. Thank you Amazon'},
#   {'id': '1337785558010097664',
#    'text': 'Just came in from @amazon.. These guys look awesome!! #mickeymouse https://t.co/70xwtdZ90Q'},
#   {'id': '1337775972372901888',
#    'text': 'ordered a new phone case from Amazon this morning and they already delivered it last night !!!! 10/10 would recommend !'},
#   {'id': '1335304145364873217',
#    'text': 'I’m only grocery shopping with @AmazonFresh from now on, my experience has been amazing they got all my monies 😩😩😩😩'},
#   {'id': '1337568075806347268', 'text': 'Amazon Prime is the best 😁'},
#   {'id': '1337465553003360256', 'text': 'Shoutout to Amazon!!!'},
#   {'id': '1337570790473142273',
#    'text': 'I have so many packages to wrap, is it acceptable to leave them under the tree in the Amazon packaging. This is the year to do it'},
#   {'id': '1337233842831159297',
#    'text': 'Should I just go ahead and start buying things off my Amazon list for myself'},
#   {'id': '1337569175179460609', 'text': '@amazon love you guys'},
#   {'id': '1337230391036444672',
#    'text': "One of the BEST $10 purchases I've made off Amazon!!! https://t.co/ophw9LjGNR"},
#   {'id': '1336788323474567168',
#    'text': 'My first Christmas orders from Amazon came in today and I am SO EXCITED 🥰'},
#   {'id': '1336784595782496256',
#    'text': 'can’t believe this is my first time shopping for groceries on amazon... such a time saver!'},
#   {'id': '1337184605514866698',
#    'text': '@amazon Thank you for the wonderful gifts Liam is sure to enjoy them.❤️❤️❤️🎁'},
#   {'id': '1337515649321603073', 'text': ':) when i see Amazon packages'},
#   {'id': '1337157608470437889',
#    'text': 'Can we talk about how the Amazon van on the app has changed to a sleigh so cute! https://t.co/Jd3vKA36it'},
#   {'id': '1337506412138819584',
#    'text': 'Someone delete my Amazon app please 🥴🙏 https://t.co/afZzY7f9Na'},
#   {'id': '1337531182825807875',
#    'text': 'Amazon gift wrapping is continually the best $5 I ever spend all year.'},
#   {'id': '1337453016807579654',
#    'text': 'Love you @amazon and ur amazing customer service'},
#   {'id': '1337485786590097408',
#    'text': '@amazon @amazon they would love that, details sent'},
#   {'id': '1337500581930340357',
#    'text': 'The pandemic has foisted upon all of us so many new things. \n\nSome awful, most crappy, but a few ok.\n\nThe daily arrival of the Amazon Prime truck with the evening’s #Hanukkah gifts is the closest many of us Jews will get to a Santa experience. And it’s pretty pretty good.'},
#   {'id': '1337454419303161856',
#    'text': '@amazon He’s a huge @Roblox &amp; @_GeometryDash_  fan! Likes to build his own world. Not sure where he gets it.😊'},
#   {'id': '1337496915206926338',
#    'text': 'Just got an Amazon package and I honestly don’t remember what I ordered this time 🤦🏽\u200d♀️'},
#   {'id': '1336346804363948034',
#    'text': 'When making a list of MVPs for the year, Black women deserve to be singled out. Doing far more than their share!\n\nI’m partnering w/ @amazonmusic to give back to @EmwgI. Proud to join Amazon in fulfilling Amazon Smile charity lists this holiday season. 🎁🌟 #DeliveringSmiles'},
#   {'id': '1336485799307698178',
#    'text': ".@amazon doesn't need to make a Christmas Alexa ad now. https://t.co/iTiMeKnzjA"},
#   {'id': '1337482763197435907',
#    'text': '@amazon how do I get your delivery guys to stop pulling up on my private land swapping delivery parcels and shouting out loud while I’m trying to work?'},
#   {'id': '1337441952178978816',
#    'text': 'I ordered something from Amazon yesterday it’s already out for delivery 😂'}],
#  'errors': [{'detail': 'Could not find tweet with ids: [1337542713709740035].',
#    'parameter': 'ids',
#    'resource_type': 'tweet',
#    'title': 'Not Found Error',
#    'type': 'https://api.twitter.com/2/problems/resource-not-found',
#    'value': '1337542713709740035'}]}

# %%
id_text_list = dataDict['data']
text_list = [x['text'] for x in id_text_list]

# %%
# list of tweets texts
text_list
# Out:
# ['@amazon Her name is Izzy! :)',
#  "Got some amazon packages and had sibling open them and put them under the tree for me. Thank you santa's elves #tbtbsanta",
#  "@amazon Hahaha she's super creative. Loves to make stuff, arts &amp; crafts, drawing, painting, etc. She's a smart cookie for sure 😂❤",
#  'I love Amazon Fresh. I can have all my groceries delivered in two hours 🙌🏻 https://t.co/8qcBdOh3wy',
#  "This purple wig is so pretty! Amazon is awesome for wigs. I'm barely getting by mentally at work and doing this is an amazing release for me. https://t.co/mqQaSWCf6a",
#  'When your parents live out of state and they bought your presents on Amazon but you also buy shit on Amazon so you have to ask permission to open your own packages cause you don’t want to ruin Christmas https://t.co/rDikf3T7qe',
#  'Amazon never fail me ain’t lying 🤣🥴.',
#  'Christmas time is oh so cozy at my apartment! 1st Christmas here&amp; I absolutely love it! ❤️🌟🎄✨ My Christmas tree skirt is from @amazon 🥰 https://t.co/NUdM88qenq',
#  "Working on school stuff with my 6yo daughter*\n\n6yo: How do you spell 'want'?\n\nMe: Try to sound it out, please.\n\n6yo: ALEXA! HOW DO YOU SPELL WANT?!\n\nAlexa: Want is spelled... w-a-n-t\n\nMe:...\n\nAlexa is now muted.\n\n#parenting #dadlife #alexastop",
#  'Dear Amazon prime, you a real one for those of us who have to wait till payday to buy Christmas presents. ‘Preciate ya',
#  'Why yes, I did search for “Bulbasaur Planter” on Amazon because I was looking to make my desk a little more adorable. https://t.co/ukbXCyP3Pd',
#  'Welp people, momlady sezs “time to send the returns back to Amazon”😹😹😹\nWinkie be jokin ya. They not send me back😼😼🐾they lubs me https://t.co/unFaCZpR5z',
#  "I have to give a HUGE shoutout to @amazon for hooking myself and my little fur family up with some gifts! Jackson &amp; Lincoln love their gifts. I'm super excited I got the tetris lights I've been looking at for awhile! We are so grateful that you did this for us. Thank you!!💕 https://t.co/HBqWYAk4G4",
#  'Max: Mom!! Amazon messed up my order! I ordered treats but they sent me a kitten in a box!! 😺🐾 Can we send her back?? 😹🐾 \nWe hope everyone is having a nice Sunday ☀️\n\n#CatsOfTwitter  #cats #catboxsunday https://t.co/9lXlpPQk6Q',
#  'I need to order so much stuff on amazon 😩',
#  '@amazon I recently purchased a magnetic phone holder from you and I pulled it off and it’s cracked my phone https://t.co/vRgTDbGmKB',
#  'I’m excited to get my supernatural merch I’ve ordered off of Amazon in the mail new shirt, new string bag and my dean amulet necklace to come in yes 👍',
#  'I ordered 3 books from Amazon, 2 books came yesterday &amp; one arrived this morning~❤💕❤ https://t.co/9qN1BVh6rA',
#  'Amazon prime has been my best friend. Need something for the baby? Bet order it real quick, here within hours or the next day. LIFESAVER 😆',
#  'God I love my echo products!! I just used my echo show to broadcast revile through my whole house to wake up my daughters!! #prouddadmoment oh FYI they weren’t amused!',
#  'Amazon prime is amazing lol',
#  'How brilliant is this - my @amazon delivery vehicle is a sleigh😆🎅🏻🎄 https://t.co/XNASd20MaE',
#  '@AmazonHelp I submitted my info, thanks!',
#  'Finally done with all my Christmas shopping. Thank you Amazon',
#  'Just came in from @amazon.. These guys look awesome!! #mickeymouse https://t.co/70xwtdZ90Q',
#  'ordered a new phone case from Amazon this morning and they already delivered it last night !!!! 10/10 would recommend !',
#  'I’m only grocery shopping with @AmazonFresh from now on, my experience has been amazing they got all my monies 😩😩😩😩',
#  'Amazon Prime is the best 😁',
#  'Shoutout to Amazon!!!',
#  'I have so many packages to wrap, is it acceptable to leave them under the tree in the Amazon packaging. This is the year to do it',
#  'Should I just go ahead and start buying things off my Amazon list for myself',
#  '@amazon love you guys',
#  "One of the BEST $10 purchases I've made off Amazon!!! https://t.co/ophw9LjGNR",
#  'My first Christmas orders from Amazon came in today and I am SO EXCITED 🥰',
#  'can’t believe this is my first time shopping for groceries on amazon... such a time saver!',
#  '@amazon Thank you for the wonderful gifts Liam is sure to enjoy them.❤️❤️❤️🎁',
#  ':) when i see Amazon packages',
#  'Can we talk about how the Amazon van on the app has changed to a sleigh so cute! https://t.co/Jd3vKA36it',
#  'Someone delete my Amazon app please 🥴🙏 https://t.co/afZzY7f9Na',
#  'Amazon gift wrapping is continually the best $5 I ever spend all year.',
#  'Love you @amazon and ur amazing customer service',
#  '@amazon @amazon they would love that, details sent',
#  'The pandemic has foisted upon all of us so many new things. \n\nSome awful, most crappy, but a few ok.\n\nThe daily arrival of the Amazon Prime truck with the evening’s #Hanukkah gifts is the closest many of us Jews will get to a Santa experience. And it’s pretty pretty good.',
#  '@amazon He’s a huge @Roblox &amp; @_GeometryDash_  fan! Likes to build his own world. Not sure where he gets it.😊',
#  'Just got an Amazon package and I honestly don’t remember what I ordered this time 🤦🏽\u200d♀️',
#  'When making a list of MVPs for the year, Black women deserve to be singled out. Doing far more than their share!\n\nI’m partnering w/ @amazonmusic to give back to @EmwgI. Proud to join Amazon in fulfilling Amazon Smile charity lists this holiday season. 🎁🌟 #DeliveringSmiles',
#  ".@amazon doesn't need to make a Christmas Alexa ad now. https://t.co/iTiMeKnzjA",
#  '@amazon how do I get your delivery guys to stop pulling up on my private land swapping delivery parcels and shouting out loud while I’m trying to work?',
#  'I ordered something from Amazon yesterday it’s already out for delivery 😂']

# %% [markdown]
# ### To Be Replaced
# - New lines, i.e "\n", with fullstops
#
# ### To Be Distilled
# - Mentions, e.g @amazon
# - Links
# - Emojis
# - Numbers
# - Special Characters, e.g ' ! ', ' : ', ' ) ', ' " ', ' / ', and ' # '. They do not include ".", ",", or " ' "

# %%
# replace new lines with a fullstop
text_list = [filterData.replaceNewLinesWith(x, '.') for x in text_list]

# alternatively, replace with a space

# %%
# Distill
temReLis = [con_REs.MENTIONS, con_REs.LINKS, con_REs.HASHTAG, con_REs.EMOJIS, con_REs.NUMBERS, con_REs.SPECIAL_CHAR]
text_list = [filterData.filterStrFromReList(temReLis, x) for x in text_list]

# %%
text_list
# Out:
# [' Her name is Izzy ',
#  'Got some amazon packages and had sibling open them and put them under the tree for me. Thank you santas elves ',
#  ' Hahaha shes super creative. Loves to make stuff arts amp crafts drawing painting etc. Shes a smart cookie for sure ',
#  'I love Amazon Fresh. I can have all my groceries delivered in two hours  ',
#  'This purple wig is so pretty Amazon is awesome for wigs. Im barely getting by mentally at work and doing this is an amazing release for me. ',
#  'When your parents live out of state and they bought your presents on Amazon but you also buy shit on Amazon so you have to ask permission to open your own packages cause you dont want to ruin Christmas ',
#  'Amazon never fail me aint lying .',
#  'Christmas time is oh so cozy at my apartment st Christmas hereamp I absolutely love it  My Christmas tree skirt is from   ',
#  'Working on school stuff with my yo daughter.yo How do you spell want.Me Try to sound it out please..yo ALEXA HOW DO YOU SPELL WANT.Alexa Want is spelled... want.Me....Alexa is now muted..  ',
#  'Dear Amazon prime you a real one for those of us who have to wait till payday to buy Christmas presents. Preciate ya',
#  'Why yes I did search for Bulbasaur Planter on Amazon because I was looking to make my desk a little more adorable. ',
#  'Welp people momlady sezs time to send the returns back to Amazon.Winkie be jokin ya. They not send me backthey lubs me ',
#  'I have to give a HUGE shoutout to  for hooking myself and my little fur family up with some gifts Jackson amp Lincoln love their gifts. Im super excited I got the tetris lights Ive been looking at for awhile We are so grateful that you did this for us. Thank you ',
#  'Max Mom Amazon messed up my order I ordered treats but they sent me a kitten in a box  Can we send her back  .We hope everyone is having a nice Sunday .    ',
#  'I need to order so much stuff on amazon ',
#  ' I recently purchased a magnetic phone holder from you and I pulled it off and its cracked my phone ',
#  'Im excited to get my supernatural merch Ive ordered off of Amazon in the mail new shirt new string bag and my dean amulet necklace to come in yes ',
#  'I ordered  books from Amazon  books came yesterday amp one arrived this morning ',
#  'Amazon prime has been my best friend. Need something for the baby Bet order it real quick here within hours or the next day. LIFESAVER ',
#  'God I love my echo products I just used my echo show to broadcast revile through my whole house to wake up my daughters  oh FYI they werent amused',
#  'Amazon prime is amazing lol',
#  'How brilliant is this  my  delivery vehicle is a sleigh ',
#  ' I submitted my info thanks',
#  'Finally done with all my Christmas shopping. Thank you Amazon',
#  'Just came in from  These guys look awesome  ',
#  'ordered a new phone case from Amazon this morning and they already delivered it last night   would recommend ',
#  'Im only grocery shopping with  from now on my experience has been amazing they got all my monies ',
#  'Amazon Prime is the best ',
#  'Shoutout to Amazon',
#  'I have so many packages to wrap is it acceptable to leave them under the tree in the Amazon packaging. This is the year to do it',
#  'Should I just go ahead and start buying things off my Amazon list for myself',
#  ' love you guys',
#  'One of the BEST  purchases Ive made off Amazon ',
#  'My first Christmas orders from Amazon came in today and I am SO EXCITED ',
#  'cant believe this is my first time shopping for groceries on amazon... such a time saver',
#  ' Thank you for the wonderful gifts Liam is sure to enjoy them.',
#  ' when i see Amazon packages',
#  'Can we talk about how the Amazon van on the app has changed to a sleigh so cute ',
#  'Someone delete my Amazon app please  ',
#  'Amazon gift wrapping is continually the best  I ever spend all year.',
#  'Love you  and ur amazing customer service',
#  '  they would love that details sent',
#  'The pandemic has foisted upon all of us so many new things. .Some awful most crappy but a few ok..The daily arrival of the Amazon Prime truck with the evenings  gifts is the closest many of us Jews will get to a Santa experience. And its pretty pretty good.',
#  ' Hes a huge  amp   fan Likes to build his own world. Not sure where he gets it.',
#  'Just got an Amazon package and I honestly dont remember what I ordered this time ',
#  'When making a list of MVPs for the year Black women deserve to be singled out. Doing far more than their share.Im partnering w  to give back to  Proud to join Amazon in fulfilling Amazon Smile charity lists this holiday season.  ',
#  '. doesnt need to make a Christmas Alexa ad now. ',
#  ' how do I get your delivery guys to stop pulling up on my private land swapping delivery parcels and shouting out loud while Im trying to work',
#  'I ordered something from Amazon yesterday its already out for delivery ']

# %%
text_list = [filterData.stripBegEnd(x) for x in text_list]

# %%
text_list
# Out:
# ['Her name is Izzy',
#  'Got some amazon packages and had sibling open them and put them under the tree for me. Thank you santas elves',
#  'Hahaha shes super creative. Loves to make stuff arts amp crafts drawing painting etc. Shes a smart cookie for sure',
#  'I love Amazon Fresh. I can have all my groceries delivered in two hours',
#  'This purple wig is so pretty Amazon is awesome for wigs. Im barely getting by mentally at work and doing this is an amazing release for me',
#  'When your parents live out of state and they bought your presents on Amazon but you also buy shit on Amazon so you have to ask permission to open your own packages cause you dont want to ruin Christmas',
#  'Amazon never fail me aint lying',
#  'Christmas time is oh so cozy at my apartment st Christmas hereamp I absolutely love it  My Christmas tree skirt is from',
#  'Working on school stuff with my yo daughter.yo How do you spell want.Me Try to sound it out please..yo ALEXA HOW DO YOU SPELL WANT.Alexa Want is spelled... want.Me....Alexa is now muted',
#  'Dear Amazon prime you a real one for those of us who have to wait till payday to buy Christmas presents. Preciate ya',
#  'Why yes I did search for Bulbasaur Planter on Amazon because I was looking to make my desk a little more adorable',
#  'Welp people momlady sezs time to send the returns back to Amazon.Winkie be jokin ya. They not send me backthey lubs me',
#  'I have to give a HUGE shoutout to  for hooking myself and my little fur family up with some gifts Jackson amp Lincoln love their gifts. Im super excited I got the tetris lights Ive been looking at for awhile We are so grateful that you did this for us. Thank you',
#  'Max Mom Amazon messed up my order I ordered treats but they sent me a kitten in a box  Can we send her back  .We hope everyone is having a nice Sunday',
#  'I need to order so much stuff on amazon',
#  'I recently purchased a magnetic phone holder from you and I pulled it off and its cracked my phone',
#  'Im excited to get my supernatural merch Ive ordered off of Amazon in the mail new shirt new string bag and my dean amulet necklace to come in yes',
#  'I ordered  books from Amazon  books came yesterday amp one arrived this morning',
#  'Amazon prime has been my best friend. Need something for the baby Bet order it real quick here within hours or the next day. LIFESAVER',
#  'God I love my echo products I just used my echo show to broadcast revile through my whole house to wake up my daughters  oh FYI they werent amused',
#  'Amazon prime is amazing lol',
#  'How brilliant is this  my  delivery vehicle is a sleigh',
#  'I submitted my info thanks',
#  'Finally done with all my Christmas shopping. Thank you Amazon',
#  'Just came in from  These guys look awesome',
#  'ordered a new phone case from Amazon this morning and they already delivered it last night   would recommend',
#  'Im only grocery shopping with  from now on my experience has been amazing they got all my monies',
#  'Amazon Prime is the best',
#  'Shoutout to Amazon',
#  'I have so many packages to wrap is it acceptable to leave them under the tree in the Amazon packaging. This is the year to do it',
#  'Should I just go ahead and start buying things off my Amazon list for myself',
#  'love you guys',
#  'One of the BEST  purchases Ive made off Amazon',
#  'My first Christmas orders from Amazon came in today and I am SO EXCITED',
#  'cant believe this is my first time shopping for groceries on amazon... such a time saver',
#  'Thank you for the wonderful gifts Liam is sure to enjoy them',
#  'when i see Amazon packages',
#  'Can we talk about how the Amazon van on the app has changed to a sleigh so cute',
#  'Someone delete my Amazon app please',
#  'Amazon gift wrapping is continually the best  I ever spend all year',
#  'Love you  and ur amazing customer service',
#  'they would love that details sent',
#  'The pandemic has foisted upon all of us so many new things. .Some awful most crappy but a few ok..The daily arrival of the Amazon Prime truck with the evenings  gifts is the closest many of us Jews will get to a Santa experience. And its pretty pretty good',
#  'Hes a huge  amp   fan Likes to build his own world. Not sure where he gets it',
#  'Just got an Amazon package and I honestly dont remember what I ordered this time',
#  'When making a list of MVPs for the year Black women deserve to be singled out. Doing far more than their share.Im partnering w  to give back to  Proud to join Amazon in fulfilling Amazon Smile charity lists this holiday season',
#  'doesnt need to make a Christmas Alexa ad now',
#  'how do I get your delivery guys to stop pulling up on my private land swapping delivery parcels and shouting out loud while Im trying to work',
#  'I ordered something from Amazon yesterday its already out for delivery']

# %%
# don't use dot, i.e period "." here
text_list = [filterData.removeDuplicatedCharList(x, [' ']) for x in text_list]
text_list = [filterData.removeDuplicatedPeriods(x) for x in text_list]

# %%
text_list
# Out:
# ['Her name is Izzy',
#  'Got some amazon packages and had sibling open them and put them under the tree for me. Thank you santas elves',
#  'Hahaha shes super creative. Loves to make stuff arts amp crafts drawing painting etc. Shes a smart cookie for sure',
#  'I love Amazon Fresh. I can have all my groceries delivered in two hours',
#  'This purple wig is so pretty Amazon is awesome for wigs. Im barely getting by mentally at work and doing this is an amazing release for me',
#  'When your parents live out of state and they bought your presents on Amazon but you also buy shit on Amazon so you have to ask permission to open your own packages cause you dont want to ruin Christmas',
#  'Amazon never fail me aint lying',
#  'Christmas time is oh so cozy at my apartment st Christmas hereamp I absolutely love it My Christmas tree skirt is from',
#  'Working on school stuff with my yo daughter.yo How do you spell want.Me Try to sound it out please.yo ALEXA HOW DO YOU SPELL WANT.Alexa Want is spelled. want.Me.Alexa is now muted',
#  'Dear Amazon prime you a real one for those of us who have to wait till payday to buy Christmas presents. Preciate ya',
#  'Why yes I did search for Bulbasaur Planter on Amazon because I was looking to make my desk a little more adorable',
#  'Welp people momlady sezs time to send the returns back to Amazon.Winkie be jokin ya. They not send me backthey lubs me',
#  'I have to give a HUGE shoutout to for hooking myself and my little fur family up with some gifts Jackson amp Lincoln love their gifts. Im super excited I got the tetris lights Ive been looking at for awhile We are so grateful that you did this for us. Thank you',
#  'Max Mom Amazon messed up my order I ordered treats but they sent me a kitten in a box Can we send her back .We hope everyone is having a nice Sunday',
#  'I need to order so much stuff on amazon',
#  'I recently purchased a magnetic phone holder from you and I pulled it off and its cracked my phone',
#  'Im excited to get my supernatural merch Ive ordered off of Amazon in the mail new shirt new string bag and my dean amulet necklace to come in yes',
#  'I ordered books from Amazon books came yesterday amp one arrived this morning',
#  'Amazon prime has been my best friend. Need something for the baby Bet order it real quick here within hours or the next day. LIFESAVER',
#  'God I love my echo products I just used my echo show to broadcast revile through my whole house to wake up my daughters oh FYI they werent amused',
#  'Amazon prime is amazing lol',
#  'How brilliant is this my delivery vehicle is a sleigh',
#  'I submitted my info thanks',
#  'Finally done with all my Christmas shopping. Thank you Amazon',
#  'Just came in from These guys look awesome',
#  'ordered a new phone case from Amazon this morning and they already delivered it last night would recommend',
#  'Im only grocery shopping with from now on my experience has been amazing they got all my monies',
#  'Amazon Prime is the best',
#  'Shoutout to Amazon',
#  'I have so many packages to wrap is it acceptable to leave them under the tree in the Amazon packaging. This is the year to do it',
#  'Should I just go ahead and start buying things off my Amazon list for myself',
#  'love you guys',
#  'One of the BEST purchases Ive made off Amazon',
#  'My first Christmas orders from Amazon came in today and I am SO EXCITED',
#  'cant believe this is my first time shopping for groceries on amazon. such a time saver',
#  'Thank you for the wonderful gifts Liam is sure to enjoy them',
#  'when i see Amazon packages',
#  'Can we talk about how the Amazon van on the app has changed to a sleigh so cute',
#  'Someone delete my Amazon app please',
#  'Amazon gift wrapping is continually the best I ever spend all year',
#  'Love you and ur amazing customer service',
#  'they would love that details sent',
#  'The pandemic has foisted upon all of us so many new things. .Some awful most crappy but a few ok.The daily arrival of the Amazon Prime truck with the evenings gifts is the closest many of us Jews will get to a Santa experience. And its pretty pretty good',
#  'Hes a huge amp fan Likes to build his own world. Not sure where he gets it',
#  'Just got an Amazon package and I honestly dont remember what I ordered this time',
#  'When making a list of MVPs for the year Black women deserve to be singled out. Doing far more than their share.Im partnering w to give back to Proud to join Amazon in fulfilling Amazon Smile charity lists this holiday season',
#  'doesnt need to make a Christmas Alexa ad now',
#  'how do I get your delivery guys to stop pulling up on my private land swapping delivery parcels and shouting out loud while Im trying to work',
#  'I ordered something from Amazon yesterday its already out for delivery']

# %%
text_list = [filterData.removeDuplicatedCharSeq(x) for x in text_list]

# %%
text_list
# Out:
# ['Her name is Izzy',
#  'Got some amazon packages and had sibling open them and put them under the tree for me.Thank you santas elves',
#  'Hahaha shes super creative.Loves to make stuff arts amp crafts drawing painting etc.Shes a smart cookie for sure',
#  'I love Amazon Fresh.I can have all my groceries delivered in two hours',
#  'This purple wig is so pretty Amazon is awesome for wigs.Im barely getting by mentally at work and doing this is an amazing release for me',
#  'When your parents live out of state and they bought your presents on Amazon but you also buy shit on Amazon so you have to ask permission to open your own packages cause you dont want to ruin Christmas',
#  'Amazon never fail me aint lying',
#  'Christmas time is oh so cozy at my apartment st Christmas hereamp I absolutely love it My Christmas tree skirt is from',
#  'Working on school stuff with my yo daughter.yo How do you spell want.Me Try to sound it out please.yo ALEXA HOW DO YOU SPELL WANT.Alexa Want is spelled.want.Me.Alexa is now muted',
#  'Dear Amazon prime you a real one for those of us who have to wait till payday to buy Christmas presents.Preciate ya',
#  'Why yes I did search for Bulbasaur Planter on Amazon because I was looking to make my desk a little more adorable',
#  'Welp people momlady sezs time to send the returns back to Amazon.Winkie be jokin ya.They not send me backthey lubs me',
#  'I have to give a HUGE shoutout to for hooking myself and my little fur family up with some gifts Jackson amp Lincoln love their gifts.Im super excited I got the tetris lights Ive been looking at for awhile We are so grateful that you did this for us.Thank you',
#  'Max Mom Amazon messed up my order I ordered treats but they sent me a kitten in a box Can we send her back.We hope everyone is having a nice Sunday',
#  'I need to order so much stuff on amazon',
#  'I recently purchased a magnetic phone holder from you and I pulled it off and its cracked my phone',
#  'Im excited to get my supernatural merch Ive ordered off of Amazon in the mail new shirt new string bag and my dean amulet necklace to come in yes',
#  'I ordered books from Amazon books came yesterday amp one arrived this morning',
#  'Amazon prime has been my best friend.Need something for the baby Bet order it real quick here within hours or the next day.LIFESAVER',
#  'God I love my echo products I just used my echo show to broadcast revile through my whole house to wake up my daughters oh FYI they werent amused',
#  'Amazon prime is amazing lol',
#  'How brilliant is this my delivery vehicle is a sleigh',
#  'I submitted my info thanks',
#  'Finally done with all my Christmas shopping.Thank you Amazon',
#  'Just came in from These guys look awesome',
#  'ordered a new phone case from Amazon this morning and they already delivered it last night would recommend',
#  'Im only grocery shopping with from now on my experience has been amazing they got all my monies',
#  'Amazon Prime is the best',
#  'Shoutout to Amazon',
#  'I have so many packages to wrap is it acceptable to leave them under the tree in the Amazon packaging.This is the year to do it',
#  'Should I just go ahead and start buying things off my Amazon list for myself',
#  'love you guys',
#  'One of the BEST purchases Ive made off Amazon',
#  'My first Christmas orders from Amazon came in today and I am SO EXCITED',
#  'cant believe this is my first time shopping for groceries on amazon.such a time saver',
#  'Thank you for the wonderful gifts Liam is sure to enjoy them',
#  'when i see Amazon packages',
#  'Can we talk about how the Amazon van on the app has changed to a sleigh so cute',
#  'Someone delete my Amazon app please',
#  'Amazon gift wrapping is continually the best I ever spend all year',
#  'Love you and ur amazing customer service',
#  'they would love that details sent',
#  'The pandemic has foisted upon all of us so many new things.Some awful most crappy but a few ok.The daily arrival of the Amazon Prime truck with the evenings gifts is the closest many of us Jews will get to a Santa experience.And its pretty pretty good',
#  'Hes a huge amp fan Likes to build his own world.Not sure where he gets it',
#  'Just got an Amazon package and I honestly dont remember what I ordered this time',
#  'When making a list of MVPs for the year Black women deserve to be singled out.Doing far more than their share.Im partnering w to give back to Proud to join Amazon in fulfilling Amazon Smile charity lists this holiday season',
#  'doesnt need to make a Christmas Alexa ad now',
#  'how do I get your delivery guys to stop pulling up on my private land swapping delivery parcels and shouting out loud while Im trying to work',
#  'I ordered something from Amazon yesterday its already out for delivery']

# %% [markdown]
# ### Chunk Tweets of Multiple Sentences
# by separating on fullstops

# %%
new_text_list = []
for el in text_list:
    new_text_list = new_text_list + el.split('.')

# %%
new_text_list
# Out:
# ['Her name is Izzy',
#  'Got some amazon packages and had sibling open them and put them under the tree for me',
#  'Thank you santas elves',
#  'Hahaha shes super creative',
#  'Loves to make stuff arts amp crafts drawing painting etc',
#  'Shes a smart cookie for sure',
#  'I love Amazon Fresh',
#  'I can have all my groceries delivered in two hours',
#  'This purple wig is so pretty Amazon is awesome for wigs',
#  'Im barely getting by mentally at work and doing this is an amazing release for me',
#  'When your parents live out of state and they bought your presents on Amazon but you also buy shit on Amazon so you have to ask permission to open your own packages cause you dont want to ruin Christmas',
#  'Amazon never fail me aint lying',
#  'Christmas time is oh so cozy at my apartment st Christmas hereamp I absolutely love it My Christmas tree skirt is from',
#  'Working on school stuff with my yo daughter',
#  'yo How do you spell want',
#  'Me Try to sound it out please',
#  'yo ALEXA HOW DO YOU SPELL WANT',
#  'Alexa Want is spelled',
#  'want',
#  'Me',
#  'Alexa is now muted',
#  'Dear Amazon prime you a real one for those of us who have to wait till payday to buy Christmas presents',
#  'Preciate ya',
#  'Why yes I did search for Bulbasaur Planter on Amazon because I was looking to make my desk a little more adorable',
#  'Welp people momlady sezs time to send the returns back to Amazon',
#  'Winkie be jokin ya',
#  'They not send me backthey lubs me',
#  'I have to give a HUGE shoutout to for hooking myself and my little fur family up with some gifts Jackson amp Lincoln love their gifts',
#  'Im super excited I got the tetris lights Ive been looking at for awhile We are so grateful that you did this for us',
#  'Thank you',
#  'Max Mom Amazon messed up my order I ordered treats but they sent me a kitten in a box Can we send her back',
#  'We hope everyone is having a nice Sunday',
#  'I need to order so much stuff on amazon',
#  'I recently purchased a magnetic phone holder from you and I pulled it off and its cracked my phone',
#  'Im excited to get my supernatural merch Ive ordered off of Amazon in the mail new shirt new string bag and my dean amulet necklace to come in yes',
#  'I ordered books from Amazon books came yesterday amp one arrived this morning',
#  'Amazon prime has been my best friend',
#  'Need something for the baby Bet order it real quick here within hours or the next day',
#  'LIFESAVER',
#  'God I love my echo products I just used my echo show to broadcast revile through my whole house to wake up my daughters oh FYI they werent amused',
#  'Amazon prime is amazing lol',
#  'How brilliant is this my delivery vehicle is a sleigh',
#  'I submitted my info thanks',
#  'Finally done with all my Christmas shopping',
#  'Thank you Amazon',
#  'Just came in from These guys look awesome',
#  'ordered a new phone case from Amazon this morning and they already delivered it last night would recommend',
#  'Im only grocery shopping with from now on my experience has been amazing they got all my monies',
#  'Amazon Prime is the best',
#  'Shoutout to Amazon',
#  'I have so many packages to wrap is it acceptable to leave them under the tree in the Amazon packaging',
#  'This is the year to do it',
#  'Should I just go ahead and start buying things off my Amazon list for myself',
#  'love you guys',
#  'One of the BEST purchases Ive made off Amazon',
#  'My first Christmas orders from Amazon came in today and I am SO EXCITED',
#  'cant believe this is my first time shopping for groceries on amazon',
#  'such a time saver',
#  'Thank you for the wonderful gifts Liam is sure to enjoy them',
#  'when i see Amazon packages',
#  'Can we talk about how the Amazon van on the app has changed to a sleigh so cute',
#  'Someone delete my Amazon app please',
#  'Amazon gift wrapping is continually the best I ever spend all year',
#  'Love you and ur amazing customer service',
#  'they would love that details sent',
#  'The pandemic has foisted upon all of us so many new things',
#  'Some awful most crappy but a few ok',
#  'The daily arrival of the Amazon Prime truck with the evenings gifts is the closest many of us Jews will get to a Santa experience',
#  'And its pretty pretty good',
#  'Hes a huge amp fan Likes to build his own world',
#  'Not sure where he gets it',
#  'Just got an Amazon package and I honestly dont remember what I ordered this time',
#  'When making a list of MVPs for the year Black women deserve to be singled out',
#  'Doing far more than their share',
#  'Im partnering w to give back to Proud to join Amazon in fulfilling Amazon Smile charity lists this holiday season',
#  'doesnt need to make a Christmas Alexa ad now',
#  'how do I get your delivery guys to stop pulling up on my private land swapping delivery parcels and shouting out loud while Im trying to work',
#  'I ordered something from Amazon yesterday its already out for delivery']

# %%
new_text_list = filterData.lowerAndTermsList_docList_in(new_text_list)

# %%
new_text_list = filterData.removeStopwordsFromDocList(new_text_list)

# %%
new_text_list
# Out:
# [['name', 'izzy'],
#  ['got', 'amazon', 'packages', 'sibling', 'open', 'put', 'tree'],
#  ['thank', 'santas', 'elves'],
#  ['hahaha', 'shes', 'super', 'creative'],
#  ['loves',
#   'make',
#   'stuff',
#   'arts',
#   'amp',
#   'crafts',
#   'drawing',
#   'painting',
#   'etc'],
#  ['shes', 'smart', 'cookie', 'sure'],
#  ['love', 'amazon', 'fresh'],
#  ['groceries', 'delivered', 'two', 'hours'],
#  ['purple', 'wig', 'pretty', 'amazon', 'awesome', 'wigs'],
#  ['im', 'barely', 'getting', 'mentally', 'work', 'amazing', 'release'],
#  ['parents',
#   'live',
#   'state',
#   'bought',
#   'presents',
#   'amazon',
#   'also',
#   'buy',
#   'shit',
#   'amazon',
#   'ask',
#   'permission',
#   'open',
#   'packages',
#   'cause',
#   'dont',
#   'want',
#   'ruin',
#   'christmas'],
#  ['amazon', 'never', 'fail', 'aint', 'lying'],
#  ['christmas',
#   'time',
#   'oh',
#   'cozy',
#   'apartment',
#   'st',
#   'christmas',
#   'hereamp',
#   'absolutely',
#   'love',
#   'christmas',
#   'tree',
#   'skirt'],
#  ['working', 'school', 'stuff', 'yo', 'daughter'],
#  ['yo', 'spell', 'want'],
#  ['try', 'sound', 'please'],
#  ['yo', 'alexa', 'spell', 'want'],
#  ['alexa', 'want', 'spelled'],
#  ['want'],
#  [],
#  ['alexa', 'muted'],
#  ['dear',
#   'amazon',
#   'prime',
#   'real',
#   'one',
#   'us',
#   'wait',
#   'till',
#   'payday',
#   'buy',
#   'christmas',
#   'presents'],
#  ['preciate', 'ya'],
#  ['yes',
#   'search',
#   'bulbasaur',
#   'planter',
#   'amazon',
#   'looking',
#   'make',
#   'desk',
#   'little',
#   'adorable'],
#  ['welp',
#   'people',
#   'momlady',
#   'sezs',
#   'time',
#   'send',
#   'returns',
#   'back',
#   'amazon'],
#  ['winkie', 'jokin', 'ya'],
#  ['send', 'backthey', 'lubs'],
#  ['give',
#   'huge',
#   'shoutout',
#   'hooking',
#   'little',
#   'fur',
#   'family',
#   'gifts',
#   'jackson',
#   'amp',
#   'lincoln',
#   'love',
#   'gifts'],
#  ['im',
#   'super',
#   'excited',
#   'got',
#   'tetris',
#   'lights',
#   'ive',
#   'looking',
#   'awhile',
#   'grateful',
#   'us'],
#  ['thank'],
#  ['max',
#   'mom',
#   'amazon',
#   'messed',
#   'order',
#   'ordered',
#   'treats',
#   'sent',
#   'kitten',
#   'box',
#   'send',
#   'back'],
#  ['hope', 'everyone', 'nice', 'sunday'],
#  ['need', 'order', 'much', 'stuff', 'amazon'],
#  ['recently',
#   'purchased',
#   'magnetic',
#   'phone',
#   'holder',
#   'pulled',
#   'cracked',
#   'phone'],
#  ['im',
#   'excited',
#   'get',
#   'supernatural',
#   'merch',
#   'ive',
#   'ordered',
#   'amazon',
#   'mail',
#   'new',
#   'shirt',
#   'new',
#   'string',
#   'bag',
#   'dean',
#   'amulet',
#   'necklace',
#   'come',
#   'yes'],
#  ['ordered',
#   'books',
#   'amazon',
#   'books',
#   'came',
#   'yesterday',
#   'amp',
#   'one',
#   'arrived',
#   'morning'],
#  ['amazon', 'prime', 'best', 'friend'],
#  ['need',
#   'something',
#   'baby',
#   'bet',
#   'order',
#   'real',
#   'quick',
#   'within',
#   'hours',
#   'next',
#   'day'],
#  ['lifesaver'],
#  ['god',
#   'love',
#   'echo',
#   'products',
#   'used',
#   'echo',
#   'show',
#   'broadcast',
#   'revile',
#   'whole',
#   'house',
#   'wake',
#   'daughters',
#   'oh',
#   'fyi',
#   'werent',
#   'amused'],
#  ['amazon', 'prime', 'amazing', 'lol'],
#  ['brilliant', 'delivery', 'vehicle', 'sleigh'],
#  ['submitted', 'info', 'thanks'],
#  ['finally', 'done', 'christmas', 'shopping'],
#  ['thank', 'amazon'],
#  ['came', 'guys', 'look', 'awesome'],
#  ['ordered',
#   'new',
#   'phone',
#   'case',
#   'amazon',
#   'morning',
#   'already',
#   'delivered',
#   'last',
#   'night',
#   'would',
#   'recommend'],
#  ['im', 'grocery', 'shopping', 'experience', 'amazing', 'got', 'monies'],
#  ['amazon', 'prime', 'best'],
#  ['shoutout', 'amazon'],
#  ['many',
#   'packages',
#   'wrap',
#   'acceptable',
#   'leave',
#   'tree',
#   'amazon',
#   'packaging'],
#  ['year'],
#  ['go', 'ahead', 'start', 'buying', 'things', 'amazon', 'list'],
#  ['love', 'guys'],
#  ['one', 'best', 'purchases', 'ive', 'made', 'amazon'],
#  ['first', 'christmas', 'orders', 'amazon', 'came', 'today', 'excited'],
#  ['cant', 'believe', 'first', 'time', 'shopping', 'groceries', 'amazon'],
#  ['time', 'saver'],
#  ['thank', 'wonderful', 'gifts', 'liam', 'sure', 'enjoy'],
#  ['see', 'amazon', 'packages'],
#  ['talk', 'amazon', 'van', 'app', 'changed', 'sleigh', 'cute'],
#  ['someone', 'delete', 'amazon', 'app', 'please'],
#  ['amazon',
#   'gift',
#   'wrapping',
#   'continually',
#   'best',
#   'ever',
#   'spend',
#   'year'],
#  ['love', 'ur', 'amazing', 'customer', 'service'],
#  ['would', 'love', 'details', 'sent'],
#  ['pandemic', 'foisted', 'upon', 'us', 'many', 'new', 'things'],
#  ['awful', 'crappy', 'ok'],
#  ['daily',
#   'arrival',
#   'amazon',
#   'prime',
#   'truck',
#   'evenings',
#   'gifts',
#   'closest',
#   'many',
#   'us',
#   'jews',
#   'get',
#   'santa',
#   'experience'],
#  ['pretty', 'pretty', 'good'],
#  ['hes', 'huge', 'amp', 'fan', 'likes', 'build', 'world'],
#  ['sure', 'gets'],
#  ['got',
#   'amazon',
#   'package',
#   'honestly',
#   'dont',
#   'remember',
#   'ordered',
#   'time'],
#  ['making', 'list', 'mvps', 'year', 'black', 'women', 'deserve', 'singled'],
#  ['far', 'share'],
#  ['im',
#   'partnering',
#   'w',
#   'give',
#   'back',
#   'proud',
#   'join',
#   'amazon',
#   'fulfilling',
#   'amazon',
#   'smile',
#   'charity',
#   'lists',
#   'holiday',
#   'season'],
#  ['doesnt', 'need', 'make', 'christmas', 'alexa', 'ad'],
#  ['get',
#   'delivery',
#   'guys',
#   'stop',
#   'pulling',
#   'private',
#   'land',
#   'swapping',
#   'delivery',
#   'parcels',
#   'shouting',
#   'loud',
#   'im',
#   'trying',
#   'work'],
#  ['ordered', 'something', 'amazon', 'yesterday', 'already', 'delivery']]
